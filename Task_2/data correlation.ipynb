# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
#importing the housing data and removed the last 18 rows of the dataset and saving to a new csv file

pd.read_csv('Housing_data-Final-1.csv')[:-18].to_csv(r'housing-data.csv', index = False)

# %%
#reading the new csv file into a dataframe
df = pd.read_csv('housing-data.csv')

# %%
df.head()
# Out:
#        Suburb Type      Price  Distance  Zipcode  #Bedroom  #Bathroom  \
# 0  Abbotsford    h  1165000.0       2.5   3067.0       3.0        2.0
# 1  Abbotsford    h  1050000.0       2.5   3067.0       2.0        1.0
# 2  Abbotsford    h  1465000.0       2.5   3067.0       3.0        2.0
# 3  Abbotsford    h   911000.0       3.0   3067.0       2.0        1.0
# 4  Abbotsford    h  1635000.0       3.0   3067.0       3.0        1.0
#
#    #-Car Garage  Lot_size            Region_name  Property_count
# 0           0.0      92.0  Northern Metropolitan          4019.0
# 1           0.0     129.0  Northern Metropolitan          4019.0
# 2           0.0     134.0  Northern Metropolitan          4019.0
# 3           0.0     141.0  Northern Metropolitan          4019.0
# 4           0.0     142.0  Northern Metropolitan          4019.0

# %%
#calculate the correlation using the pearson method
df_pearson = df.corr(method="pearson")
df_pearson
# Out:
#                    Price  Distance   Zipcode  #Bedroom  #Bathroom  \
# Price           1.000000 -0.262172  0.113908  0.403400   0.435291
# Distance       -0.262172  1.000000  0.468404  0.217200   0.091317
# Zipcode         0.113908  0.468404  1.000000  0.083226   0.127024
# #Bedroom        0.403400  0.217200  0.083226  1.000000   0.574920
# #Bathroom       0.435291  0.091317  0.127024  0.574920   1.000000
# #-Car Garage    0.180185  0.225112  0.055421  0.355356   0.286204
# Lot_size        0.023186  0.010856  0.026732  0.003015   0.028555
# Property_count -0.024929 -0.022572  0.057510 -0.056742  -0.042758
#
#                 #-Car Garage  Lot_size  Property_count
# Price               0.180185  0.023186       -0.024929
# Distance            0.225112  0.010856       -0.022572
# Zipcode             0.055421  0.026732        0.057510
# #Bedroom            0.355356  0.003015       -0.056742
# #Bathroom           0.286204  0.028555       -0.042758
# #-Car Garage        1.000000  0.015653       -0.005251
# Lot_size            0.015653  1.000000       -0.002748
# Property_count     -0.005251 -0.002748        1.000000

# %%
#Lets plot a graph and see how this looks like on graph

sb.heatmap(df_pearson, 
            xticklabels=df_pearson.columns,
            yticklabels=df_pearson.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.5)
# Out:
# <AxesSubplot:>

# %%
#calculate the correlation using the spearman method
df_spearman = df.corr(method="spearman")
df_spearman
# Out:
#                    Price  Distance   Zipcode  #Bedroom  #Bathroom  \
# Price           1.000000 -0.303331  0.290693  0.416054   0.377741
# Distance       -0.303331  1.000000  0.255564  0.263386   0.117169
# Zipcode         0.290693  0.255564  1.000000  0.081319   0.154166
# #Bedroom        0.416054  0.263386  0.081319  1.000000   0.573017
# #Bathroom       0.377741  0.117169  0.154166  0.573017   1.000000
# #-Car Garage    0.195904  0.293469  0.070750  0.417260   0.329654
# Lot_size        0.153018  0.314696  0.131020  0.331171   0.133931
# Property_count  0.032981 -0.105569  0.128873 -0.037891  -0.018157
#
#                 #-Car Garage  Lot_size  Property_count
# Price               0.195904  0.153018        0.032981
# Distance            0.293469  0.314696       -0.105569
# Zipcode             0.070750  0.131020        0.128873
# #Bedroom            0.417260  0.331171       -0.037891
# #Bathroom           0.329654  0.133931       -0.018157
# #-Car Garage        1.000000  0.345781       -0.019393
# Lot_size            0.345781  1.000000       -0.023945
# Property_count     -0.019393 -0.023945        1.000000

# %%
#Lets plot a graph and see how this looks like on graph

sb.heatmap(df_pearson, 
            xticklabels=df_spearman.columns,
            yticklabels=df_spearman.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.5)
# Out:
# <AxesSubplot:>

# %%
#calculate the correlation using the Kendall method
df_kendall = df.corr(method="kendall")
df_kendall
# Out:
#                    Price  Distance   Zipcode  #Bedroom  #Bathroom  \
# Price           1.000000 -0.205374  0.193832  0.325742   0.302211
# Distance       -0.205374  1.000000  0.189624  0.201493   0.092320
# Zipcode         0.193832  0.189624  1.000000  0.061870   0.121256
# #Bedroom        0.325742  0.201493  0.061870  1.000000   0.526843
# #Bathroom       0.302211  0.092320  0.121256  0.526843   1.000000
# #-Car Garage    0.149467  0.226411  0.054654  0.365299   0.299984
# Lot_size        0.106458  0.219702  0.089443  0.267186   0.106513
# Property_count  0.023538 -0.076148  0.082197 -0.028811  -0.014304
#
#                 #-Car Garage  Lot_size  Property_count
# Price               0.149467  0.106458        0.023538
# Distance            0.226411  0.219702       -0.076148
# Zipcode             0.054654  0.089443        0.082197
# #Bedroom            0.365299  0.267186       -0.028811
# #Bathroom           0.299984  0.106513       -0.014304
# #-Car Garage        1.000000  0.267826       -0.014997
# Lot_size            0.267826  1.000000       -0.016063
# Property_count     -0.014997 -0.016063        1.000000

# %%
#Lets plot a graph and see how this looks like on graph

sb.heatmap(df_kendall, 
            xticklabels=df_kendall.columns,
            yticklabels=df_kendall.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.5)
# Out:
# <AxesSubplot:>

# %%
#we have plotted 3 different method of correllation.
#If the goal is to predict what features will affect the price of the house or apartment, we can see from the three
#correllation method that number of bedroom "#Bedroom" will greatly affect the pricing. Now lets calculate individually the
#correllation of price against all the features in the dataset

# %%
#using price as the the goal or prediction value, we add it to a seperate dataframe
price_df = df["Price"]

# %%
#calculate the correllation coefficient with the pearson method
df.corrwith(price_df,method="pearson",axis=0)
# Out:
# Price             1.000000
# Distance         -0.262172
# Zipcode           0.113908
# #Bedroom          0.403400
# #Bathroom         0.435291
# #-Car Garage      0.180185
# Lot_size          0.023186
# Property_count   -0.024929
# dtype: float64

# %%
#calculate the correllation coefficient with the spearman method
df.corrwith(price_df,method="spearman",axis=0)
# Out:
# Price             1.000000
# Distance         -0.303331
# Zipcode           0.290693
# #Bedroom          0.416054
# #Bathroom         0.377741
# #-Car Garage      0.195904
# Lot_size          0.153018
# Property_count    0.032981
# dtype: float64

# %%
#calculate the correllation coefficient with the kendall method
df.corrwith(price_df,method="kendall",axis=0)
# Out:
# Price             1.000000
# Distance         -0.205374
# Zipcode           0.193832
# #Bedroom          0.325742
# #Bathroom         0.302211
# #-Car Garage      0.149467
# Lot_size          0.106458
# Property_count    0.023538
# dtype: float64

# %%
## we can see that across all the three methods for correllation, bedroom and bathroom are the the sole reason why price
#of a particular housing will be expensive.

#However we can see that, the pearson correllation coefficient says otherwise. It says that the bathroom is responsible for
#increase in pricing unlike spearman and kendall method
